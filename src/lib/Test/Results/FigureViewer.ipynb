# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#num_0 = pd.read_csv('Datasets\\test_manifold_3d_0.csv')
#num_1 = pd.read_csv('Datasets\\test_manifold_3d_1.csv')
inter = pd.read_csv('Datasets\\intersection_3d.csv')
    
plt.figure(figsize=(15, 15))
plt.scatter(num_0['x'], num_0['y'], s=0.5, c='r')
plt.scatter(num_1['x'], num_1['y'], s=0.5, c='b')
plt.scatter(inter['x'], inter['y'], s=20, c='g')
